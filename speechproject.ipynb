# %%
import os
import numpy as np
import librosa
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

# Reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Emotion mappings
ravdess_emotions = {
    '01': 'neutral', '02': 'calm', '03': 'happy', '04': 'sad',
    '05': 'angry', '06': 'fearful', '07': 'disgust', '08': 'surprised'
}
cremad_emotions = {
    'NEU': 'neutral', 'HAP': 'happy', 'SAD': 'sad',
    'ANG': 'angry', 'FEA': 'fearful', 'DIS': 'disgust'
}

# %%
# Label Encoder
label_encoder = LabelEncoder()
label_encoder.fit(list(set(ravdess_emotions.values()) | set(cremad_emotions.values())))

# Data augmentation
def add_noise(audio, noise_factor=0.005):
    noise = np.random.randn(len(audio))
    return (audio + noise_factor * noise).astype(np.float32)

# Feature extraction
def extract_features(file_path, max_pad_len=174, augment=False):
    try:
        audio, sr = librosa.load(file_path, sr=22050)
        if augment:
            audio = add_noise(audio)
        mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=40)
        pad_width = max_pad_len - mfcc.shape[1]
        if pad_width > 0:
            mfcc = np.pad(mfcc, ((0, 0), (0, pad_width)), mode='constant')
        else:
            mfcc = mfcc[:, :max_pad_len]
        return mfcc
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return None

# Load dataset
def load_dataset(ravdess_path, cremad_path):
    X, y = [], []

    # RAVDESS
    for root, _, files in os.walk(ravdess_path):
        for file in files:
            if not file.endswith('.wav') or '-' not in file:
                continue
            parts = file.split('-')
            if len(parts) < 3:
                continue
            emo_code = parts[2]
            label = ravdess_emotions.get(emo_code)
            if label:
                path = os.path.join(root, file)
                for aug in [False, True]:
                    feat = extract_features(path, augment=aug)
                    if feat is not None:
                        X.append(feat)
                        y.append(label)

    # CREMA-D
    for root, _, files in os.walk(cremad_path):
        for file in files:
            if not file.endswith('.wav') or '_' not in file:
                continue
            parts = file.split('_')
            if len(parts) < 3:
                continue
            emo_code = parts[-2]
            label = cremad_emotions.get(emo_code)
            if label:
                path = os.path.join(root, file)
                for aug in [False, True]:
                    feat = extract_features(path, augment=aug)
                    if feat is not None:
                        X.append(feat)
                        y.append(label)

    return np.array(X), np.array(y)

# Paths to datasets (update accordingly)
ravdess_path = r'/Users/Appy/work/project_speech/archive (1)'
cremad_path = r'/Users/Appy/work/project_speech/AudioWAV'

# Load and prepare data
X, y = load_dataset(ravdess_path, cremad_path)
if len(X) == 0:
    raise RuntimeError("No data loaded. Check dataset paths and structure.")

# %%
y_cremad
# Out:
# ['angry',
#  'angry',
#  'neutral',
#  'neutral',
#  'disgust',
#  'disgust',
#  'sad',
#  'fearful',
#  'sad',
#  'happy',
#  'fearful',
#  'sad',
#  'happy',
#  'happy',
#  'happy',
#  'fearful',
#  'fearful',
#  'angry',
#  'angry',
#  'disgust',
#  'disgust',
#  'angry',
#  'sad',
#  'neutral',
#  'sad',
#  'neutral',
#  'angry',
#  'happy',
#  'fearful',
#  'neutral',
#  'disgust',
#  'disgust',
#  'happy',
#  'fearful',
#  'disgust',
#  'happy',
#  'fearful',
#  'neutral',
#  'angry',
#  'neutral',
#  'neutral',
#  'angry',
#  'angry',
#  'disgust',
#  'disgust',
#  'sad',
#  'sad',
#  'happy',
#  'happy',
#  'fearful',
#  'fearful',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'fearful',
#  'angry',
#  'fearful',
#  'fearful',
#  'happy',
#  'disgust',
#  'disgust',
#  'happy',
#  'neutral',
#  'neutral',
#  'angry',
#  'angry',
#  'sad',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'disgust',
#  'disgust',
#  'disgust',
#  'disgust',
#  'disgust',
#  'fearful',
#  'disgust',
#  'disgust',
#  'disgust',
#  'happy',
#  'happy',
#  'disgust',
#  'disgust',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'neutral',
#  'fearful',
#  'happy',
#  'angry',
#  'disgust',
#  'angry',
#  'happy',
#  'sad',
#  'sad',
#  'fearful',
#  'neutral',
#  'disgust',
#  'happy',
#  'sad',
#  'fearful',
#  'fearful',
#  'fearful',
#  'angry',
#  'angry',
#  'disgust',
#  'disgust',
#  'neutral',
#  'neutral',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'neutral',
#  'neutral',
#  'fearful',
#  'fearful',
#  'happy',
#  'angry',
#  'angry',
#  'angry',
#  'disgust',
#  'disgust',
#  'fearful',
#  'fearful',
#  'happy',
#  'happy',
#  'sad',
#  'fearful',
#  'happy',
#  'disgust',
#  'disgust',
#  'neutral',
#  'fearful',
#  'disgust',
#  'happy',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'neutral',
#  'disgust',
#  'happy',
#  'neutral',
#  'neutral',
#  'disgust',
#  'disgust',
#  'angry',
#  'angry',
#  'fearful',
#  'fearful',
#  'happy',
#  'happy',
#  'sad',
#  'sad',
#  'neutral',
#  'neutral',
#  'happy',
#  'angry',
#  'angry',
#  'disgust',
#  'happy',
#  'neutral',
#  'happy',
#  'disgust',
#  'fearful',
#  'fearful',
#  'neutral',
#  'neutral',
#  'angry',
#  'angry',
#  'fearful',
#  'disgust',
#  'disgust',
#  'sad',
#  'disgust',
#  'disgust',
#  'neutral',
#  'sad',
#  'disgust',
#  'disgust',
#  'disgust',
#  'disgust',
#  'disgust',
#  'disgust',
#  'happy',
#  'fearful',
#  'angry',
#  'angry',
#  'disgust',
#  'sad',
#  'sad',
#  'happy',
#  'fearful',
#  'fearful',
#  'happy',
#  'happy',
#  'angry',
#  'angry',
#  'angry',
#  'neutral',
#  'neutral',
#  'disgust',
#  'disgust',
#  'disgust',
#  'disgust',
#  'disgust',
#  'neutral',
#  'fearful',
#  'disgust',
#  'sad',
#  'sad',
#  'neutral',
#  'angry',
#  'angry',
#  'happy',
#  'happy',
#  'fearful',
#  'fearful',
#  'neutral',
#  'angry',
#  'angry',
#  'angry',
#  'neutral',
#  'neutral',
#  'fearful',
#  'disgust',
#  'happy',
#  'angry',
#  'sad',
#  'disgust',
#  'disgust',
#  'sad',
#  'happy',
#  'happy',
#  'fearful',
#  'neutral',
#  'fearful',
#  'disgust',
#  'neutral',
#  'happy',
#  'angry',
#  'angry',
#  'neutral',
#  'sad',
#  'sad',
#  'neutral',
#  'happy',
#  'disgust',
#  'disgust',
#  'happy',
#  'fearful',
#  'angry',
#  'angry',
#  'fearful',
#  'happy',
#  'happy',
#  'neutral',
#  'fearful',
#  'fearful',
#  'fearful',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'happy',
#  'happy',
#  'angry',
#  'fearful',
#  'fearful',
#  'angry',
#  'neutral',
#  'angry',
#  'angry',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'angry',
#  'angry',
#  'happy',
#  'neutral',
#  'neutral',
#  'fearful',
#  'angry',
#  'angry',
#  'angry',
#  'angry',
#  'disgust',
#  'angry',
#  'angry',
#  'fearful',
#  'sad',
#  'sad',
#  'fearful',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'fearful',
#  'fearful',
#  'happy',
#  'sad',
#  'disgust',
#  'sad',
#  'happy',
#  'happy',
#  'fearful',
#  'neutral',
#  'sad',
#  'sad',
#  'fearful',
#  'happy',
#  'happy',
#  'fearful',
#  'fearful',
#  'happy',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'fearful',
#  'fearful',
#  'happy',
#  'happy',
#  'fearful',
#  'fearful',
#  'angry',
#  'angry',
#  'disgust',
#  'disgust',
#  'neutral',
#  'neutral',
#  'sad',
#  'sad',
#  'neutral',
#  'neutral',
#  'angry',
#  'angry',
#  'fearful',
#  'fearful',
#  'happy',
#  'happy',
#  'disgust',
#  'sad',
#  'sad',
#  'happy',
#  'disgust',
#  'angry',
#  'angry',
#  'disgust',
#  'happy',
#  'neutral',
#  'fearful',
#  'neutral',
#  'angry',
#  'neutral',
#  'fearful',
#  'fearful',
#  'neutral',
#  'happy',
#  'happy',
#  'disgust',
#  'sad',
#  'sad',
#  'disgust',
#  'sad',
#  'angry',
#  'fearful',
#  'fearful',
#  'angry',
#  'disgust',
#  'happy',
#  'happy',
#  'disgust',
#  'neutral',
#  'neutral',
#  'angry',
#  'angry',
#  'sad',
#  'sad',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'fearful',
#  'angry',
#  'angry',
#  'fearful',
#  'happy',
#  'happy',
#  'neutral',
#  'neutral',
#  'disgust',
#  'fearful',
#  'fearful',
#  'happy',
#  'happy',
#  'sad',
#  'sad',
#  'neutral',
#  'fearful',
#  'neutral',
#  'happy',
#  'angry',
#  'angry',
#  'angry',
#  'angry',
#  'angry',
#  'angry',
#  'disgust',
#  'angry',
#  'angry',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'angry',
#  'angry',
#  'happy',
#  'fearful',
#  'disgust',
#  'fearful',
#  'happy',
#  'happy',
#  'sad',
#  'fearful',
#  'fearful',
#  'neutral',
#  'sad',
#  'happy',
#  'fearful',
#  'fearful',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'fearful',
#  'fearful',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'fearful',
#  'fearful',
#  'angry',
#  'angry',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'sad',
#  'disgust',
#  'disgust',
#  'happy',
#  'disgust',
#  'disgust',
#  'fearful',
#  'disgust',
#  'fearful',
#  'fearful',
#  'disgust',
#  'happy',
#  'disgust',
#  'disgust',
#  'disgust',
#  'disgust',
#  'angry',
#  'happy',
#  'sad',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'angry',
#  'angry',
#  'happy',
#  'disgust',
#  'disgust',
#  'happy',
#  'fearful',
#  'neutral',
#  'fearful',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'fearful',
#  'fearful',
#  'sad',
#  'fearful',
#  'fearful',
#  'happy',
#  'happy',
#  'fearful',
#  'neutral',
#  'neutral',
#  'happy',
#  'disgust',
#  'disgust',
#  'angry',
#  'angry',
#  'sad',
#  'angry',
#  'angry',
#  'angry',
#  'angry',
#  'sad',
#  'angry',
#  'disgust',
#  'disgust',
#  'disgust',
#  'sad',
#  'angry',
#  'angry',
#  'angry',
#  'sad',
#  'sad',
#  'disgust',
#  'disgust',
#  'fearful',
#  'neutral',
#  'fearful',
#  'happy',
#  'happy',
#  'fearful',
#  'sad',
#  'happy',
#  'angry',
#  'angry',
#  'happy',
#  'disgust',
#  'disgust',
#  'fearful',
#  'fearful',
#  'sad',
#  'neutral',
#  'happy',
#  'neutral',
#  'angry',
#  'neutral',
#  'sad',
#  'happy',
#  'disgust',
#  'happy',
#  'disgust',
#  'disgust',
#  'fearful',
#  'disgust',
#  'angry',
#  'disgust',
#  'disgust',
#  'sad',
#  'disgust',
#  'disgust',
#  'disgust',
#  'disgust',
#  'fearful',
#  'neutral',
#  'neutral',
#  'angry',
#  'angry',
#  'neutral',
#  'fearful',
#  'fearful',
#  'disgust',
#  'happy',
#  'neutral',
#  'happy',
#  'disgust',
#  'angry',
#  'happy',
#  'happy',
#  'sad',
#  'sad',
#  'neutral',
#  'neutral',
#  'happy',
#  'fearful',
#  'fearful',
#  'happy',
#  'happy',
#  'neutral',
#  'fearful',
#  'neutral',
#  'happy',
#  'angry',
#  'angry',
#  'disgust',
#  'disgust',
#  'neutral',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'angry',
#  'sad',
#  'happy',
#  'angry',
#  'angry',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'sad',
#  'fearful',
#  'disgust',
#  'disgust',
#  'happy',
#  'happy',
#  'neutral',
#  'fearful',
#  'fearful',
#  'angry',
#  'happy',
#  'angry',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'fearful',
#  'angry',
#  'angry',
#  'neutral',
#  'happy',
#  'fearful',
#  'sad',
#  'neutral',
#  'fearful',
#  'disgust',
#  'happy',
#  'disgust',
#  'fearful',
#  'neutral',
#  'fearful',
#  'fearful',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'angry',
#  'happy',
#  'disgust',
#  'fearful',
#  'fearful',
#  'happy',
#  'happy',
#  'fearful',
#  'sad',
#  'sad',
#  'fearful',
#  'happy',
#  'happy',
#  'sad',
#  'disgust',
#  'sad',
#  'happy',
#  'fearful',
#  'fearful',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'fearful',
#  'sad',
#  'sad',
#  'fearful',
#  'neutral',
#  'angry',
#  'angry',
#  'neutral',
#  'neutral',
#  'angry',
#  'angry',
#  'angry',
#  'angry',
#  'neutral',
#  'neutral',
#  'angry',
#  'angry',
#  'angry',
#  'angry',
#  'neutral',
#  'sad',
#  'neutral',
#  'angry',
#  'fearful',
#  'fearful',
#  'angry',
#  'happy',
#  'happy',
#  'disgust',
#  'neutral',
#  'neutral',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'fearful',
#  'fearful',
#  'neutral',
#  'happy',
#  'happy',
#  'neutral',
#  'fearful',
#  'angry',
#  'angry',
#  'fearful',
#  'happy',
#  'disgust',
#  'disgust',
#  'happy',
#  'sad',
#  'sad',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'angry',
#  'angry',
#  'fearful',
#  'happy',
#  'fearful',
#  'happy',
#  'happy',
#  'angry',
#  'neutral',
#  'disgust',
#  'sad',
#  'sad',
#  'neutral',
#  'angry',
#  'angry',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'fearful',
#  'disgust',
#  'fearful',
#  'happy',
#  'disgust',
#  'happy',
#  'neutral',
#  'neutral',
#  'sad',
#  'disgust',
#  'angry',
#  'angry',
#  'sad',
#  'sad',
#  'neutral',
#  'neutral',
#  'disgust',
#  'angry',
#  'angry',
#  'disgust',
#  'disgust',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'fearful',
#  'fearful',
#  'sad',
#  'sad',
#  'happy',
#  'fearful',
#  'fearful',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'sad',
#  'fearful',
#  'fearful',
#  'sad',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'happy',
#  'sad',
#  'sad',
#  'happy',
#  'fearful',
#  'fearful',
#  'angry',
#  'happy',
#  'sad',
#  'fearful',
#  'fearful',
#  'sad',
#  'happy',
#  'happy',
#  'fearful',
#  'disgust',
#  'fearful',
#  'disgust',
#  'happy',
#  'disgust',
#  'neutral',
#  'neutral',
#  'angry',
#  'angry',
#  'angry',
#  'angry',
#  'angry',
#  'neutral',
#  'neutral',
#  'sad',
#  'angry',
#  'angry',
#  'neutral',
#  'neutral',
#  'angry',
#  'angry',
#  'angry',
#  'angry',
#  'sad',
#  'sad',
#  'disgust',
#  'disgust',
#  'happy',
#  'happy',
#  'fearful',
#  'fearful',
#  'happy',
#  'happy',
#  'fearful',
#  'angry',
#  'angry',
#  'fearful',
#  'neutral',
#  'neutral',
#  'disgust',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'sad',
#  'sad',
#  'neutral',
#  'neutral',
#  'angry',
#  'angry',
#  'disgust',
#  'happy',
#  'happy',
#  'disgust',
#  'angry',
#  'fearful',
#  'fearful',
#  'angry',
#  'sad',
#  'sad',
#  'happy',
#  'fearful',
#  'happy',
#  'happy',
#  'fearful',
#  'fearful',
#  'angry',
#  'sad',
#  'neutral',
#  'angry',
#  'angry',
#  'neutral',
#  'neutral',
#  'sad',
#  'sad',
#  'happy',
#  'happy',
#  'disgust',
#  'fearful',
#  'disgust',
#  'fearful',
#  'neutral',
#  'neutral',
#  'angry',
#  'angry',
#  'happy',
#  'disgust',
#  'sad',
#  'sad',
#  'angry',
#  'angry',
#  'neutral',
#  'neutral',
#  'disgust',
#  'disgust',
#  'fearful',
#  'fearful',
#  'happy',
#  'happy',
#  'fearful',
#  'fearful',
#  'happy',
#  'happy',
#  'neutral',
#  'neutral',
#  'disgust',
#  'disgust',
#  'angry',
#  'angry',
#  'happy',
#  'sad',
#  'sad',
#  'angry',
#  'angry',
#  'disgust',
#  'sad',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'disgust',
#  'disgust',
#  'fearful',
#  'fearful',
#  'disgust',
#  'neutral',
#  'neutral',
#  'sad',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'angry',
#  'angry',
#  'neutral',
#  'sad',
#  'angry',
#  'happy',
#  'happy',
#  'fearful',
#  'fearful',
#  'happy',
#  'fearful',
#  'sad',
#  'sad',
#  'disgust',
#  'neutral',
#  'disgust',
#  'happy',
#  'happy',
#  'disgust',
#  'angry',
#  'fearful',
#  'fearful',
#  'angry',
#  'angry',
#  'neutral',
#  'neutral',
#  'happy',
#  'sad',
#  'neutral',
#  'sad',
#  'sad',
#  'disgust',
#  'sad',
#  'disgust',
#  'sad',
#  'neutral',
#  'neutral',
#  'disgust',
#  'happy',
#  'happy',
#  'fearful',
#  'angry',
#  'angry',
#  'fearful',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'fearful',
#  ...]

# %%
y_encoded = label_encoder.transform(y)
y_categorical = to_categorical(y_encoded)
X = X[..., np.newaxis]

X_train, X_test, y_train, y_test = train_test_split(X, y_categorical, test_size=0.2, stratify=y, random_state=42)

# Build CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(40, 174, 1)),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.3),

    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.3),

    Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.3),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.4),
    Dense(len(label_encoder.classes_), activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train with EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)
model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=100, callbacks=[early_stop], verbose=1)

# Evaluate
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {test_acc:.4f}")

# Save model
model.save('cnn_emotion_model_combined.keras')
# Out:
# /Users/sanjaykalkal/Library/Python/3.9/lib/python/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 41s 77ms/step - accuracy: 0.2390 - loss: 2.4551 - val_accuracy: 0.2952 - val_loss: 1.6431
# Epoch 2/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 44s 85ms/step - accuracy: 0.2962 - loss: 1.6574 - val_accuracy: 0.3904 - val_loss: 1.4936
# Epoch 3/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 48s 93ms/step - accuracy: 0.3291 - loss: 1.6050 - val_accuracy: 0.4442 - val_loss: 1.4461
# Epoch 4/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 59s 114ms/step - accuracy: 0.3551 - loss: 1.5615 - val_accuracy: 0.4883 - val_loss: 1.3771
# Epoch 5/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 55s 107ms/step - accuracy: 0.3851 - loss: 1.5076 - val_accuracy: 0.4289 - val_loss: 1.4552
# Epoch 6/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 55s 106ms/step - accuracy: 0.4025 - loss: 1.4737 - val_accuracy: 0.4996 - val_loss: 1.2698
# Epoch 7/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 60s 117ms/step - accuracy: 0.4157 - loss: 1.4414 - val_accuracy: 0.4962 - val_loss: 1.3031
# Epoch 8/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 60s 117ms/step - accuracy: 0.4283 - loss: 1.4047 - val_accuracy: 0.5367 - val_loss: 1.2040
# Epoch 9/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 61s 118ms/step - accuracy: 0.4478 - loss: 1.3866 - val_accuracy: 0.5461 - val_loss: 1.1939
# Epoch 10/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 57s 111ms/step - accuracy: 0.4583 - loss: 1.3502 - val_accuracy: 0.5449 - val_loss: 1.2033
# Epoch 11/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 58s 111ms/step - accuracy: 0.4675 - loss: 1.3199 - val_accuracy: 0.5607 - val_loss: 1.1772
# Epoch 12/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 57s 111ms/step - accuracy: 0.4844 - loss: 1.2884 - val_accuracy: 0.5800 - val_loss: 1.0978
# Epoch 13/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 60s
100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 52s 101ms/step - accuracy: 0.8675 - loss: 0.3716 - val_accuracy: 0.8435 - val_loss: 0.4939
# Epoch 67/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 52s 100ms/step - accuracy: 0.8668 - loss: 0.3687 - val_accuracy: 0.8414 - val_loss: 0.5142
# Epoch 68/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 52s 101ms/step - accuracy: 0.8637 - loss: 0.3686 - val_accuracy: 0.8389 - val_loss: 0.4961
# Epoch 69/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 53s 102ms/step - accuracy: 0.8674 - loss: 0.3612 - val_accuracy: 0.8443 - val_loss: 0.4984
# Epoch 70/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 52s 101ms/step - accuracy: 0.8706 - loss: 0.3501 - val_accuracy: 0.8455 - val_loss: 0.5426
# Epoch 71/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 52s 100ms/step - accuracy: 0.8755 - loss: 0.3397 - val_accuracy: 0.8450 - val_loss: 0.5013
# Epoch 72/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 52s 101ms/step - accuracy: 0.8706 - loss: 0.3426 - val_accuracy: 0.8467 - val_loss: 0.5117
# Epoch 73/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 53s 103ms/step - accuracy: 0.8799 - loss: 0.3348 - val_accuracy: 0.8540 - val_loss: 0.4894
# Epoch 74/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 53s 103ms/step - accuracy: 0.8808 - loss: 0.3279 - val_accuracy: 0.8566 - val_loss: 0.4946
# Epoch 75/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 52s 101ms/step - accuracy: 0.8845 - loss: 0.3232 - val_accuracy: 0.8552 - val_loss: 0.4930
# Epoch 76/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 52s 101ms/step - accuracy: 0.8855 - loss: 0.3178 - val_accuracy: 0.8612 - val_loss: 0.4622
# Epoch 77/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 57s 109ms/step - accuracy: 0.8852 - loss: 0.3098 - val_accuracy: 0.8554 - val_loss: 0.4921
# Epoch 78/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 137s 266ms/step - accuracy: 0.8878 - loss: 0.3088 - val_accuracy: 0.8416 - val_loss: 0.5347
# Epoch 79/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 39s 75ms/step - accuracy: 0.8855 - loss: 0.3080 - val_accuracy: 0.8593 - val_loss: 0.4923
# Epoch 80/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 43s 84ms/step - accuracy: 0.8965 - loss: 0.2901 - val_accuracy: 0.8651 - val_loss: 0.4851
# Epoch 81/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 67s 130ms/step - accuracy: 0.8979 - loss: 0.2749 - val_accuracy: 0.8615 - val_loss: 0.4742
# Epoch 82/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 55s 107ms/step - accuracy: 0.8923 - loss: 0.2919 - val_accuracy: 0.8481 - val_loss: 0.4779
# Epoch 83/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 52s 101ms/step - accuracy: 0.8939 - loss: 0.2944 - val_accuracy: 0.8620 - val_loss: 0.4633
# Epoch 84/100
# 517/517 ━━━━━━━━━━━━━━━━━━━━ 53s 102ms/step - accuracy: 0.8982 - loss: 0.2863 - val_accuracy: 0.8687 - val_loss: 0.4665
# Test Accuracy: 0.8612

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 38, 172, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 38, 172, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 19, 86, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 19, 86, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 17, 84, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 17, 84, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 42, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 42, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 6, 40, 128)     │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 6, 40, 128)     │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 3, 20, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 3, 20, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 7680)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     1,966,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │         2,056 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,184,986 (23.59 MB)
#  Trainable params: 2,061,512 (7.86 MB)
#  Non-trainable params: 448 (1.75 KB)
#  Optimizer params: 4,123,026 (15.73 MB)

# %%
def predict_emotion(file_path):
    features = extract_features(file_path, augment=False)
    if features is None:
        return "Error processing audio"
    features = features[np.newaxis, ..., np.newaxis]
    prediction = model.predict(features)
    emotion = label_encoder.inverse_transform([np.argmax(prediction)])[0]
    return emotion

# %%
# Run a prediction
if __name__ == "__main__":
    test_file = r'/Users/Appy/work/project_speech/audio/Thapar-University-Area-9_2.wav'  # Replace with valid file path

    if os.path.isfile(test_file):
        predicted = predict_emotion(test_file)
        print(f"Predicted Emotion: {predicted}")
    else:
        print("Test file not found.")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Predicted Emotion: angry
